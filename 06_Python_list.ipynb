# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvo5684/Skill_for_All/blob/python_practice/06_Python_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **List is an ordered changeable collection that holds items of different types.**

# %% [markdown]
# ## **i. Creating a list**

# %%
my_list=[] #empty list

# %%
numbers=[1,2,3,4,5]

# %%
mixed=[1,"shuvo",30.5,"food",True]

# %%
type(mixed)
# Out:
# list

# %% [markdown]
# ## **ii. Acccessing list items**

# %%
fruits=["apple","banana","cherry"]

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[0]
# Out:
# 'apple'

# %%
type(fruits[0])
# Out:
# str

# %%
fruits[-2]
# Out:
# 'banana'

# %% [markdown]
# ## **iii. Changing List itemms.**

# %%
items=["apple","banana","cherry"]

# %%
items
# Out:
# ['apple', 'banana', 'cherry']

# %%
items[2]="blueberry"

# %%
items
# Out:
# ['apple', 'banana', 'blueberry']

# %% [markdown]
# ## **iv. Adding items**

# %%
items=["apple","banana","Cherry"]

# %%
items.insert(1,"kiwi") # add at a specific index

# %%
items.append("jackfruit") # add as the last element

# %%
items
# Out:
# ['apple', 'kiwi', 'banana', 'Cherry', 'jackfruit']

# %%
items
# Out:
# ['apple', 'kiwi', 'banana', 'Cherry', 'jackfruit']

# %% [markdown]
# ## **v. Removing items**

# %%
items
# Out:
# ['apple', 'kiwi', 'kiwi', 'banana', 'Cherry', 'jackfruit', 'jackfruit']

# %%
items.remove("apple")

# %%
items
# Out:
# ['kiwi', 'kiwi', 'banana', 'Cherry', 'jackfruit', 'jackfruit']

# %%
items.pop(1)
# Out:
# 'kiwi'

# %%
items
# Out:
# ['kiwi', 'banana', 'Cherry', 'jackfruit', 'jackfruit']

# %%
del items[0]

# %%
items
# Out:
# ['banana', 'Cherry', 'jackfruit', 'jackfruit']

# %%
items.clear()

# %%
items
# Out:
# []

# %%
len(items)
# Out:
# 0

# %% [markdown]
# ## **vi. List Functions**

# %%
numbers=[9,40,5,8,20]

# %%
len(numbers)
# Out:
# 5

# %%
max(numbers)
# Out:
# 40

# %%
min(numbers)
# Out:
# 5

# %%
print(numbers.sort())
# Out:
# None

# %%
numbers.sort()

# %%
numbers
# Out:
# [5, 8, 9, 20, 40]

# %%
numbers.reverse()

# %%
numbers
# Out:
# [40, 20, 9, 8, 5]

# %%
for fruits in ["apple","banana","cherry"]:
  print(fruits)
# Out:
# apple
# banana
# cherry

# %%
fruits
# Out:
# 'cherry'
