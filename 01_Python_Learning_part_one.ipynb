# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvo5684/Skill_for_All/blob/python_practice/Python_Learning_part_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+3
# Out:
# 5

# %%
print("Hello")
# Out:
# Hello

# %%
print('hi I am new in python')
# Out:
# hi I am new in python

# %%
2*3
# Out:
# 6

# %% [markdown]
# # **Problem: Find out total monthly expense given individual expense items**

# %%
rent=1220;
gas=122;
groceries=305.5;

# %%
print(rent)
# Out:
# 1220

# %%
total=rent+gas+groceries

# %%
total
# Out:
# 1647.5

# %%
print(total)
# Out:
# 1647.5

# %%
rent=1440

# %%
rent
# Out:
# 1440

# %%
print(rent)
# Out:
# 1440

# %%
print('Expense items', rent,gas,groceries)
# Out:
# Expense items 1440 122 305.5

# %% [markdown]
# # **Variables**

# %%
x=10;
name='shamim'
pi=3.1416;
is_active=True;

# %%
is_active
# Out:
# True

# %%
pi
# Out:
# 3.1416

# %%
pi*pi
# Out:
# 9.86965056

# %%
name
# Out:
# 'shamim'

# %%
x
# Out:
# 10

# %% [markdown]
# # **Assigning values**
# 1. single assignment
# 2. multiple variables, same value
# 3. multiple variables different values

# %%
x=10

# %%
x=y=z=100

# %%
name,age,country='shuvo',32,'Bangladesh'

# %%
country
# Out:
# 'Bangladesh'

# %%
age
# Out:
# 32

# %%
name
# Out:
# 'shuvo'

# %%
x=23
n='shajib'

# %%
x=25
x='ayaat'

# %%
x
# Out:
# 'ayaat'

# %%
type(x)
# Out:
# str

# %% [markdown]
# # **GLobal vs Local Variables**

# %%
x='shafiqul' #global variable
def my_func():
  x='ayaat' #local variable
  print(x)
my_func() #call the function
print(x)  #print global variables
# Out:
# ayaat
# shafiqul

# %% [markdown]
# # **Delete Variable**

# %%
country='Bangladesh'

# %%
print('country')
# Out:
# country

# %%
print(country)
# Out:
# Bangladesh

# %%
del country

# %%
country
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-428035683.py in <cell line: 0>()
# ----> 1 country
#
# NameError: name 'country' is not defined
