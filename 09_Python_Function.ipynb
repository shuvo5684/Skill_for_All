# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvo5684/Skill_for_All/blob/python_practice/09_Python_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **A Function is a reusable block of code that perform a specific task. Functions help make a code more organised, reusable and easier to maintain.**

# %% [markdown]
# **When we make a function for the task. we need two important steps to use the finction.
# step 1:define the function
# step 2: call the function.**

# %% [markdown]
# 1. Creating a function

# %%
# function definition
def greet():
    print("Hello, welcome to Python!")
#call the function
greet()
# Out:
# Hello, welcome to Python!

# %% [markdown]
# 2. Function with parameters

# %%
def greet(name):
  print(f"Hello your name is {name}")

greet("shuvo")
# Out:
# Hello your name is shuvo

# %% [markdown]
# 3. A functions with default parameters

# %%
def python_users( name="Ayaat"):
  print(f"your name is {name}")

python_users()
python_users("shuvo")
# Out:
# your name is Ayaat
# your name is shuvo

# %% [markdown]
# 4. A Function with return value

# %%
x=5
y=10
num=add(x,y)
def add(a,b):
  total=a+b
  return total
  print("total inside the funtion: ", total)

print("Total outside the function: ", num)
# Out:
# total inside the funtion:  15
# Total outside the function:  15

# %%
clothing_expense=[10,20,58,60]
Household_expense=[1500,1200,1000]
total_clothing_expense=calculate_total(clothing_expense)
total_Household_expense=calculate_total(Household_expense)
total_expense=total_clothing_expense+total_Household_expense
print("Total Clothing Expense is: ",total_clothing_expense)
print("Total Household Expense is: ", total_Household_expense)
print("Total Expense: ", total_expense)

def calculate_total(expense):
  total=0
  for item in expense:
    total=total+item
  return total
# Out:
# Total Clothing Expense is:  148
# Total Household Expense is:  3700
# Total Expense:  3848
