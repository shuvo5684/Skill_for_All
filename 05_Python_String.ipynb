# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvo5684/Skill_for_All/blob/python_practice/String_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **String in pytho**

# %%
str1='hello'
str2="world"
str3="""this is multi
line
string using triple quotes"""

# %%
type(str1)
# Out:
# str

# %%
print(str3)
# Out:
# this is multi
# line
# string using triple quotes

# %% [markdown]
# ## **Python Indexing**

# %%
txt="python is good for all developer"

# %%
print(txt[0]) #first index value
# Out:
# p

# %%
print(txt[-1]) #lasr index value
# Out:
# r

# %%
print(txt[-2])
# Out:
# e

# %%
print(txt[-4])
# Out:
# o

# %%
print(txt[4])
# Out:
# o

# %%
print(txt[3])
# Out:
# h

# %%
print(txt[0:4]) # include index 0 and exclude index 4
# Out:
# pyth

# %% [markdown]
# ## **python slicing**

# %%
print(txt[:8])
# Out:
# python i

# %%
print(txt[8:])
# Out:
# s good for all developer

# %%
print(txt[-1]) #print last index value.
# Out:
# r

# %%
print(txt[::]) # print entire string
# Out:
# python is good for all developer

# %%
print(txt)
# Out:
# python is good for all developer

# %%
print(txt.upper())
# Out:
# PYTHON IS GOOD FOR ALL DEVELOPER

# %%
print(txt.lower())
# Out:
# python is good for all developer

# %%
print(txt.split())
# Out:
# ['python', 'is', 'good', 'for', 'all', 'developer']

# %%
print(txt.split("o"))
# Out:
# ['pyth', 'n is g', '', 'd f', 'r all devel', 'per']

# %%
print(txt.replace("developer","programmer"))
# Out:
# python is good for all programmer

# %%
print("hello" in txt)
# Out:
# False

# %%
print("programmer" not in txt)
# Out:
# True

# %%
print(txt)
# Out:
# python is good for all developer

# %% [markdown]
# ## **String concatenation and repetition**

# %%
a="hello"
b="world"

# %%
print(a+b)
# Out:
# helloworld

# %%
print(a+" "+b) # string concatenation
# Out:
# hello world

# %%
print(b*3) #string repetition
# Out:
# worldworldworld

# %%
a=23
b="hello"

# %%
str(a)+b
# Out:
# '23hello'

# %%
print(str(a)+" "+b)
# Out:
# 23 hello

# %% [markdown]
# ## **f-string(String formating)**

# %%
name="shafiqul"
age=32

# %%
print(f" my name is {name}")
# Out:
#  my name is shafiqul

# %%
print(f"i am {age} years old")
# Out:
# i am 32 years old

# %% [markdown]
# ## **Escape characrter**

# %%
print("hello\nworld") #new line
# Out:
# hello
# world

# %%
print("hello\tworld") #tab space
# Out:
# hello	world

# %%
print("he said \"python is ok\"")
# Out:
# he said "python is ok"
