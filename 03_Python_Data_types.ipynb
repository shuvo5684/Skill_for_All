# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvo5684/Skill_for_All/blob/python_practice/Data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Data types:**
# 1. Numeric types: int, float, complex.
# 2. Text type: str.
# 3. Sequence types: touple,list,range.
# 4. Mapping type: dict.
# 5. Set types: set, frozenset.
# 6. Boolean type: bool.
# 7. Binary types: bytes, bytearray, memoryview.
# 8. None type: Nonetype

# %%
x= 5
y=5.777
z=2+4j

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
print(type(x),type(y),type(z))
# Out:
# <class 'int'> <class 'float'> <class 'complex'>

# %%
M='hellow world'

# %%
type(M)
# Out:
# str

# %%
t=('Apple','Banana','Cherry')

# %%
type(t)
# Out:
# tuple

# %%
d={"name":"Shafiqul","Age":25,"City":"Dhaka"}

# %%
type(d)
# Out:
# dict

# %%
s={"Apple","Banana","Cherry"}

# %%
type(s)
# Out:
# set

# %%
L=["Apple","Banana","Cherry"]

# %%
type(L)
# Out:
# list

# %%
R=range(6)

# %%
print(R)
# Out:
# range(0, 6)

# %%
range(6)
# Out:
# range(0, 6)

# %%
type(R)
# Out:
# range

# %%
T=True

# %%
type(T)
# Out:
# bool

# %%
b=b"Hello"

# %%
type(b)
# Out:
# bytes

# %%
x=bytearray(5)

# %%
print(x)
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')

# %%
x=None

# %%
type(x)
# Out:
# NoneType

# %%
x=memoryview(bytes(5))

# %%
type(x)
# Out:
# memoryview

# %%
x=memoryview(bytearray(5))

# %%
print(x)

# %%
type(x)
# Out:
# memoryview
